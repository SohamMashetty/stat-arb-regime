# %%
import sys, os
sys.path.append(os.path.abspath("../src"))
from data_loader import load_price_data, preprocess
import matplotlib.pyplot as plt

# %%
# Load & preprocess
df = load_price_data()
df = preprocess(df)

# %%
# Plot
df.plot(title='Raw Price Data')
plt.show()
